# %%
import jsonlines

# %%
with jsonlines.open('../data/test_response.jsonl') as reader:
    
    response_list = []
    
    for response in reader:
        #print((obj.keys()))
        
        response_dict = {}
        
        response_dict['idannonce'] = response['id']
        response_dict['annotator'] = response['_session_id']
        
        if 'selected_ids' in response.keys():
            response_dict['answer'] = response['selected_ids']
        else:
            response_dict['answer'] = []
            
        response_dict['status'] = response['answer']
        response_dict['proposal_id_list'] =  [proposal['id'] for proposal in response['options']]
        
        response_list.append(response_dict)

# %%
response_list
# Out:
# [{'idannonce': '152917265',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [137918345, 152656465, 154105923]},
#  {'idannonce': '150907823',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': ['151785547'],
#   'status': 'accept',
#   'proposal_id_list': [151785547, 152595879, 154223735]},
#  {'idannonce': '153731933',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'ignore',
#   'proposal_id_list': [151131015, 154210349]},
#  {'idannonce': '149695535',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'ignore',
#   'proposal_id_list': [154564545, 150185261]},
#  {'idannonce': '150595489',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'ignore',
#   'proposal_id_list': [154104595, 154056591]},
#  {'idannonce': '151159799',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'ignore',
#   'proposal_id_list': [148947457, 142854677, 154105991, 154105017]},
#  {'idannonce': '148881165',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'reject',
#   'proposal_id_list': [154106605, 154104625]},
#  {'idannonce': '149333771',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': ['154571571'],
#   'status': 'accept',
#   'proposal_id_list': [154571571]},
#  {'idannonce': '149333771',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': ['154571571'],
#   'status': 'ignore',
#   'proposal_id_list': [154571571]},
#  {'idannonce': '154705515',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'ignore',
#   'proposal_id_list': [154583385, 154698861]},
#  {'idannonce': '152302781',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'ignore',
#   'proposal_id_list': [154104645]},
#  {'idannonce': '154711741',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'ignore',
#   'proposal_id_list': [153934247]},
#  {'idannonce': '153230135',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'ignore',
#   'proposal_id_list': [154687423, 154104533]},
#  {'idannonce': '145626751',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'ignore',
#   'proposal_id_list': [151510745, 148284577, 154304767]},
#  {'idannonce': '151409363',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'ignore',
#   'proposal_id_list': [154104577, 154181571]},
#  {'idannonce': '148276145',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'ignore',
#   'proposal_id_list': [154104625, 154105749]},
#  {'idannonce': '148560325',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'ignore',
#   'proposal_id_list': [154104253]},
#  {'idannonce': '145111403',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'ignore',
#   'proposal_id_list': [150128677, 151052293]},
#  {'idannonce': '143640641',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'ignore',
#   'proposal_id_list': [151011695, 154104275]},
#  {'idannonce': '151193763',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'reject',
#   'proposal_id_list': [153006409, 146986341]},
#  {'idannonce': '150595441',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'reject',
#   'proposal_id_list': [154560951, 154106599, 154106653]},
#  {'idannonce': '152338927',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'reject',
#   'proposal_id_list': [153185239]},
#  {'idannonce': '148947457',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'reject',
#   'proposal_id_list': [151159799, 154105991, 154105017]},
#  {'idannonce': '153922751',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'reject',
#   'proposal_id_list': [152709549, 154342789]},
#  {'idannonce': '151763965',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'ignore',
#   'proposal_id_list': [154482193, 143573271]},
#  {'idannonce': '148629713',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'ignore',
#   'proposal_id_list': [152708291, 151828083]},
#  {'idannonce': '152549053',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'ignore',
#   'proposal_id_list': [149773799, 152794709, 153361779, 154104599, 149803509]},
#  {'idannonce': '152917455',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'reject',
#   'proposal_id_list': [154104911]},
#  {'idannonce': '152430603',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'reject',
#   'proposal_id_list': [152019911, 152112787]},
#  {'idannonce': '153267117',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'reject',
#   'proposal_id_list': [152595879, 154223735]},
#  {'idannonce': '153923681',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'reject',
#   'proposal_id_list': [154194981, 151219121]},
#  {'idannonce': '153372973',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [149803509]},
#  {'idannonce': '152220675',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': ['154106615'],
#   'status': 'accept',
#   'proposal_id_list': [152590227, 154106615]},
#  {'idannonce': '150625857',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [152380729, 154656893]},
#  {'idannonce': '151927237',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [154268707, 153773471, 154072797, 154268715]},
#  {'idannonce': '152380729',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': ['150625857'],
#   'status': 'accept',
#   'proposal_id_list': [150625857, 154656893, 154787717, 151477361]},
#  {'idannonce': '153349107',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [148878621]},
#  {'idannonce': '149773799',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [152549053,
#    148967091,
#    152794709,
#    153361779,
#    154104599,
#    149803509,
#    150790843]},
#  {'idannonce': '151431309',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [152284973]},
#  {'idannonce': '148967091',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [149773799, 153361779, 154104599]},
#  {'idannonce': '151927233',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': ['131612729'],
#   'status': 'accept',
#   'proposal_id_list': [131612729, 154104585]},
#  {'idannonce': '147707003',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [154731215, 152858747]},
#  {'idannonce': '151131015',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [153731933, 154210349, 151522923, 153329467, 154104967]},
#  {'idannonce': '153778505',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [152967835, 154104519]},
#  {'idannonce': '153291975',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [153267071, 154190207]},
#  {'idannonce': '151785547',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [150907823]},
#  {'idannonce': '152699413',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [152033889, 151587069]},
#  {'idannonce': '149478087',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [154722253, 154027449]},
#  {'idannonce': '154437491',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [154609255, 154083409, 154560977]},
#  {'idannonce': '146150697',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [153188201]},
#  {'idannonce': '151927251',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': ['154106701'],
#   'status': 'reject',
#   'proposal_id_list': [154571567, 154106701]},
#  {'idannonce': '154494955',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [150189205]},
#  {'idannonce': '147244103',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [154223791]},
#  {'idannonce': '154104595',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': ['150595489'],
#   'status': 'accept',
#   'proposal_id_list': [150595489, 154056591]},
#  {'idannonce': '148227933',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [153083885, 154730443, 149181811]},
#  {'idannonce': '154722253',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [149478087, 154027449]},
#  {'idannonce': '151956631',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [143938329, 154767533, 141127617]},
#  {'idannonce': '144240037',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': ['152103519'],
#   'status': 'accept',
#   'proposal_id_list': [151522923, 153329467, 154104967, 154056599, 152103519]},
#  {'idannonce': '138838789',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [145680331, 151422235]},
#  {'idannonce': '151927599',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [151159801, 154105013]},
#  {'idannonce': '147041505',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [148924465, 154370019]},
#  {'idannonce': '153923139',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [144895721, 146598959]},
#  {'idannonce': '154104253',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [148560325]},
#  {'idannonce': '154731215',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [147707003, 152858747]},
#  {'idannonce': '152509335',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'ignore',
#   'proposal_id_list': [152380203, 154105907]},
#  {'idannonce': '152794709',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [152549053, 149773799, 153361779, 154104599, 149803509]},
#  {'idannonce': '148390971',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [151763963, 152872605]},
#  {'idannonce': '151266181',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [150933817, 152033891]},
#  {'idannonce': '151611123',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': ['154104529'],
#   'status': 'accept',
#   'proposal_id_list': [146208291, 154104529, 153123993]},
#  {'idannonce': '148924465',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [147041505]},
#  {'idannonce': '153822699',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': ['154106603'],
#   'status': 'accept',
#   'proposal_id_list': [153188201, 154106603]},
#  {'idannonce': '150189205',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [154494955, 152590227]},
#  {'idannonce': '154027449',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [149478087, 154722253]},
#  {'idannonce': '144895721',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [153923139]},
#  {'idannonce': '152380203',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [152509335, 148500761, 154105907]},
#  {'idannonce': '154564545',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [149695535, 150185261, 154425161, 152084743]},
#  {'idannonce': '145254367',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [152471403, 154105849]},
#  {'idannonce': '152260255',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': [],
#   'status': 'accept',
#   'proposal_id_list': [149940537, 149107399]},
#  {'idannonce': '152595879',
#   'annotator': 'RelatedListings-jcazes',
#   'answer': ['154223735', '153267117'],
#   'status': 'reject',
#   'proposal_id_list': [150907823, 153267117, 154223735]}]

# %%
import pandas as pd 

df = pd.DataFrame(response_list)
# Out:
# /home/jeanchristophe/.pyenv/versions/3.7.7/envs/doublons3.7/lib/python3.7/site-packages/pandas/compat/__init__.py:85: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# /home/jeanchristophe/.pyenv/versions/3.7.7/envs/doublons3.7/lib/python3.7/site-packages/pandas/compat/__init__.py:85: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
df
# Out:
#     idannonce               annotator                  answer  status  \
# 0   152917265  RelatedListings-jcazes                      []  accept
# 1   150907823  RelatedListings-jcazes             [151785547]  accept
# 2   153731933  RelatedListings-jcazes                      []  ignore
# 3   149695535  RelatedListings-jcazes                      []  ignore
# 4   150595489  RelatedListings-jcazes                      []  ignore
# ..        ...                     ...                     ...     ...
# 74  152380203  RelatedListings-jcazes                      []  accept
# 75  154564545  RelatedListings-jcazes                      []  accept
# 76  145254367  RelatedListings-jcazes                      []  accept
# 77  152260255  RelatedListings-jcazes                      []  accept
# 78  152595879  RelatedListings-jcazes  [154223735, 153267117]  reject
#
#                                 proposal_id_list
# 0              [137918345, 152656465, 154105923]
# 1              [151785547, 152595879, 154223735]
# 2                         [151131015, 154210349]
# 3                         [154564545, 150185261]
# 4                         [154104595, 154056591]
# ..                                           ...
# 74             [152509335, 148500761, 154105907]
# 75  [149695535, 150185261, 154425161, 152084743]
# 76                        [152471403, 154105849]
# 77                        [149940537, 149107399]
# 78             [150907823, 153267117, 154223735]
#
# [79 rows x 5 columns]

# %%
def prodigy_result_to_pandas():
